# %% [markdown]
# TASK ONE:EXPLORATORY DATA ANALYSIS (EDA)

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('data1.csv')

# %%
print(df.head())
print(df.shape)
print(df.info())
print(df.describe())
# Out:
#       Name  Age  Grade        Id  Gender  Salary   Bonus
# 0  Douglas   21  8.589    842302    Male   97308   6.945
# 1   Thomas   24  5.398    842517    Male   61933   0.000
# 2    Maria   31  5.450  84300903  Female  130590  11.858
# 3    Jerry   33  7.450  84348301    Male  138705   9.340
# 4    Larry   22  8.450  84358402    Male  101004   0.000
# (49, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    44 non-null     object
#  1   Age     49 non-null     int64
#  2   Grade   49 non-null     float64
#  3   Id      49 non-null     int64
#  4   Gender  44 non-null     object
#  5   Salary  49 non-null     int64
#  6   Bonus   49 non-null     float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 2.8+ KB
# None
#              Age      Grade            Id         Salary      Bonus
# count  49.000000  49.000000  4.900000e+01      49.000000  49.000000
# mean   27.408163   6.148163  2.202074e+07   94595.265306   9.853592
# std     3.962945   1.933645  3.618651e+07   30145.401869   5.456048
# min    20.000000   3.008000  8.571500e+04   36844.000000   0.000000
# 25%    24.000000   4.500000  8.525520e+05   66820.000000   6.414000
# 50%    28.000000   6.000000  8.549410e+05   97308.000000   9.340000
# 75%    31.000000   7.600000  8.511133e+06  119082.000000  13.873000
# max    36.000000   9.700000  8.571370e+07  145146.000000  19.096000

# %%
print(df.isnull().sum())

df.fillna(method='ffill', inplace=True)  #forward fill

print(df.duplicated().sum())

df.drop_duplicates(inplace=True)
# Out:
# Name      5
# Age       0
# Grade     0
# Id        0
# Gender    5
# Salary    0
# Bonus     0
# dtype: int64
# 0
# C:\Users\hp\AppData\Local\Temp\ipykernel_13168\4106838727.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  #forward fill

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))
df.hist(figsize=(10, 8), bins=40)
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df['Bonus'])
plt.show()

# %%
import numpy as np
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Grade', y='Salary', data=df)
plt.title('Grade vs. Salary')
plt.show()

# %%
# Exclude non-numeric columns for correlation
numeric_df = df.select_dtypes(include=[np.number])

# Correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Outlier detection
plt.figure(figsize=(6, 4))
sns.boxplot(df["Bonus"])
plt.title('Outlier detection')
plt.show()
